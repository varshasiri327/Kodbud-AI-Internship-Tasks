# %% [markdown]
# <a href="https://colab.research.google.com/github/varshasiri327/Kodbud-AI-Internship-Tasks/blob/main/Kodbud_Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
print("Click 'Choose Files' below to upload any photo from your computer:")
uploaded = files.upload()
# Out:
# Click 'Choose Files' below to upload any photo from your computer:
#      <input type="file" id="files-cd08e868-540c-46a4-be29-3db87568eb8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd08e868-540c-46a4-be29-3db87568eb8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
for filename in uploaded.keys():
    print(f'\nSuccessfully uploaded file: "{filename}"')
# Out:
# Successfully uploaded file: "Screenshot 2026-06-19 11.47.14 AM.png"

# %%
image = cv2.imread(filename)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# %%
for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 4)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(8, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

print(f"Result: The AI successfully found {len(faces)} face(s) in your uploaded image!")
# Out:
# Result: The AI successfully found 1 face(s) in your uploaded image!
