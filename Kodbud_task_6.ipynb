# %% [markdown]
# <a href="https://colab.research.google.com/github/varshasiri327/Kodbud-AI-Internship-Tasks/blob/main/Kodbud_task_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def get_user_choice():
    while True:
        user_choice = input("Choose your move (rock, paper, scissors, or 'quit' to end): ").lower()
        if user_choice in ['rock', 'paper', 'scissors', 'quit']:
            return user_choice
        else:
            print("Invalid choice. Please choose rock, paper, or scissors.")

def get_computer_choice():
    return random.choice(['rock', 'paper', 'scissors'])

def determine_winner(user_choice, computer_choice):
    if user_choice == computer_choice:
        return "It's a tie!"
    elif (
        (user_choice == 'rock' and computer_choice == 'scissors') or
        (user_choice == 'scissors' and computer_choice == 'paper') or
        (user_choice == 'paper' and computer_choice == 'rock')
    ):
        return "You win!"
    else:
        return "Computer wins!"

def play_game():
    user_score = 0
    computer_score = 0
    round_num = 0

    print("\n--- Welcome to Rock, Paper, Scissors! ---")
    print("Play against the computer. First to 3 wins or type 'quit' to end.")

    while user_score < 3 and computer_score < 3:
        round_num += 1
        print(f"\n--- Round {round_num} ---")

        user_choice = get_user_choice()
        if user_choice == 'quit':
            break

        computer_choice = get_computer_choice()

        print(f"You chose: {user_choice}")
        print(f"Computer chose: {computer_choice}")

        result = determine_winner(user_choice, computer_choice)
        print(result)

        if result == "You win!":
            user_score += 1
        elif result == "Computer wins!":
            computer_score += 1

        print(f"Current Score: You {user_score} - Computer {computer_score}")

    print("\n--- Game Over --- ")
    if user_score > computer_score:
        print(f"Congratulations! You won the game with a final score of {user_score} to {computer_score}!")
    elif computer_score > user_score:
        print(f"The computer won the game with a final score of {computer_score} to {user_score}. Better luck next time!")
    else:
        print(f"The game ended in a tie with a final score of {user_score} to {computer_score}!")

play_game()
# Out:
# --- Welcome to Rock, Paper, Scissors! ---
# Play against the computer. First to 3 wins or type 'quit' to end.
#
# --- Round 1 ---
# Choose your move (rock, paper, scissors, or 'quit' to end): scissors
# You chose: scissors
# Computer chose: paper
# You win!
# Current Score: You 1 - Computer 0
#
# --- Round 2 ---
# Choose your move (rock, paper, scissors, or 'quit' to end): paper
# You chose: paper
# Computer chose: paper
# It's a tie!
# Current Score: You 1 - Computer 0
#
# --- Round 3 ---
# Choose your move (rock, paper, scissors, or 'quit' to end): rock
# You chose: rock
# Computer chose: rock
# It's a tie!
# Current Score: You 1 - Computer 0
#
# --- Round 4 ---
# Choose your move (rock, paper, scissors, or 'quit' to end): scissors
# You chose: scissors
# Computer chose: scissors
# It's a tie!
# Current Score: You 1 - Computer 0
#
# --- Round 5 ---
# Choose your move (rock, paper, scissors, or 'quit' to end): quit
#
# --- Game Over ---
# ...
