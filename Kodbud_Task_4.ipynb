# %% [markdown]
# <a href="https://colab.research.google.com/github/varshasiri327/Kodbud-AI-Internship-Tasks/blob/main/Kodbud_Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

print(f"Dataset loaded! Training samples: {len(X_train)}, Testing samples: {len(X_test)}")
# Out:
# Dataset loaded! Training samples: 60000, Testing samples: 10000

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
print("\n--- Training the Neural Network Brain ---")
model.fit(X_train, y_train, epochs=3, batch_size=64)
# Out:
# --- Training the Neural Network Brain ---
# Epoch 1/3
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9149 - loss: 0.3033
# Epoch 2/3
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9594 - loss: 0.1395
# Epoch 3/3
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9714 - loss: 0.0975

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\n✅ Model Training Complete! Test Dataset Accuracy: {test_acc * 100:.2f}%")
# Out:
# ✅ Model Training Complete! Test Dataset Accuracy: 97.09%

# %%
sample_index = np.random.randint(0, len(X_test))
prediction = model.predict(np.expand_dims(X_test[sample_index], axis=0))
predicted_digit = np.argmax(prediction)
print(f"🤖 AI Prediction: The network thinks this image is the number: {predicted_digit}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 🤖 AI Prediction: The network thinks this image is the number: 5
